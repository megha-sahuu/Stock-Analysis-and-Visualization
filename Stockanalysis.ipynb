# %% [markdown]
# <a href="https://colab.research.google.com/github/megha-sahuu/Stock-Analysis-and-Visualization/blob/main/Stockanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Algorithmic Trading and Qualitative Analysis**

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import matplotlib.pyplot as plt

plt.style.use("seaborn")
# %matplotlib inline
# Out:
# <ipython-input-298-6255bfa466f9>:8: MatplotlibDeprecationWarning:
#
# The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.

# %% [markdown]
# Growth Analysis of Google

# %%
g = yf.download("GOOGL")
g
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-08-19    2.502503    2.604104    2.401401    2.511011    2.508132
# 2004-08-20    2.527778    2.729730    2.515015    2.710460    2.707353
# 2004-08-23    2.771522    2.839840    2.728979    2.737738    2.734599
# 2004-08-24    2.783784    2.792793    2.591842    2.624374    2.621365
# 2004-08-25    2.626627    2.702703    2.599600    2.652653    2.649612
# ...                ...         ...         ...         ...         ...
# 2024-08-19  165.279999  166.690002  164.259995  166.669998  166.669998
# 2024-08-20  166.899994  168.639999  166.820007  167.179993  167.179993
# 2024-08-21  165.149994  166.850006  164.669998  165.850006  165.850006
# 2024-08-22  167.259995  167.589996  163.309998  163.800003  163.800003
# 2024-08-23  164.500000  166.179993  163.830002  164.990005  164.990005
#
#                Volume
# Date
# ...

# %%
close_price_g = g.loc[:, "Close"].copy()
close_price_g.dropna(inplace=True)
plt.figure(figsize=(16,8))
plt.plot(close_price_g, color='blue', linewidth=2, linestyle='--', label='Google Close Price')
plt.fill_between(close_price_g.index, close_price_g, color='skyblue', alpha=0.3)
plt.title('Google Growth', fontsize=20)
plt.xlabel('Date', fontsize=15)
plt.ylabel('Price Growth', fontsize=15)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(fontsize=12, loc='upper left')
plt.show()

# %% [markdown]
# Growth Analysis of Microsoft

# %%
ms = yf.download("MSFT")

ms
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.059947
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062087
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063158
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061552
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060482
# ...                ...         ...         ...         ...         ...
# 2024-08-16  420.600006  421.339996  417.299988  418.470001  418.470001
# 2024-08-19  418.959991  421.750000  416.459991  421.529999  421.529999
# 2024-08-20  421.700012  425.859985  421.640015  424.799988  424.799988
# 2024-08-21  424.079987  426.399994  421.720001  424.140015  424.140015
# 2024-08-22  424.359985  426.790009  414.609985  415.549988  415.549988
#
#                 Volume
# Date
# ...

# %%
ms = yf.download("MSFT")

close_price_ms = ms.loc[:, "Close"].copy()
close_price_ms.dropna(inplace=True)

plt.figure(figsize=(16,8))
plt.plot(close_price_ms, color='blue', linewidth=2, linestyle='--')
plt.fill_between(close_price_ms.index, close_price_ms, color='skyblue', alpha=0.3)
plt.title('MSFT Closing Price', fontsize=20)
plt.xlabel('Date', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(['MSFT Close Price'], fontsize=12, loc='upper left')
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# Prepreocessing on Individual Stock

# %%
Reliance = yf.download("RELIANCE.NS", start="2015-01-01", end = "2024-08-24")
Reliance
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-01-01   405.186554   407.792389   403.975037   405.917999   381.517303
# 2015-01-02   406.009430   409.643921   404.272217   404.843658   380.507507
# 2015-01-05   404.592224   407.289520   399.609100   400.409149   376.339600
# 2015-01-06   397.734741   399.106232   380.362396   382.236786   359.259583
# 2015-01-07   382.693970   392.614471   382.648254   390.557220   367.079956
# ...                 ...          ...          ...          ...          ...
# 2024-08-19  2965.000000  2996.600098  2961.000000  2976.800049  2976.800049
# 2024-08-20  2994.449951  3007.850098  2980.050049  2991.899902  2991.899902
# 2024-08-21  2986.500000  3015.750000  2980.000000  2997.350098  2997.350098
# 2024-08-22  3006.000000  3013.000000  2981.300049  2996.250000  2996.250000
# ...

# %%
Reliance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2363 entries, 2015-01-01 to 2024-07-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2363 non-null   float64
#  1   High       2363 non-null   float64
#  2   Low        2363 non-null   float64
#  3   Close      2363 non-null   float64
#  4   Adj Close  2363 non-null   float64
#  5   Volume     2363 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 129.2 KB

# %%
Reliance.to_csv('Reliance_Stock_Data.csv')

# %%
reliance_data = pd.read_csv('Reliance_Stock_Data.csv')
reliance_data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-01-01  405.186554  407.792389  403.975037  405.917999  381.517303
# 1  2015-01-02  406.009430  409.643921  404.272217  404.843658  380.507507
# 2  2015-01-05  404.592224  407.289520  399.609100  400.409149  376.339630
# 3  2015-01-06  397.734741  399.106232  380.362396  382.236786  359.259552
# 4  2015-01-07  382.693970  392.614471  382.648254  390.557220  367.079895
#
#      Volume
# 0   1481821
# 1   3665683
# 2   5051970
# 3   9313990
# 4  10360156

# %%
reliance_data = pd.read_csv('Reliance_Stock_Data.csv', index_col=[0], parse_dates=[0])  # Omit 1st column and parse date
reliance_data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-01-01  405.186554  407.792389  403.975037  405.917999  381.517303
# 2015-01-02  406.009430  409.643921  404.272217  404.843658  380.507507
# 2015-01-05  404.592224  407.289520  399.609100  400.409149  376.339630
# 2015-01-06  397.734741  399.106232  380.362396  382.236786  359.259552
# 2015-01-07  382.693970  392.614471  382.648254  390.557220  367.079895
#
#               Volume
# Date
# 2015-01-01   1481821
# 2015-01-02   3665683
# 2015-01-05   5051970
# 2015-01-06   9313990
# 2015-01-07  10360156

# %%
close_price_reliance = reliance_data.loc[:,"Close"].copy()
close_price_reliance.to_frame()
# Out:
#                   Close
# Date
# 2015-01-01   405.917999
# 2015-01-02   404.843658
# 2015-01-05   400.409149
# 2015-01-06   382.236786
# 2015-01-07   390.557220
# ...                 ...
# 2024-07-25  2984.800049
# 2024-07-26  3018.050049
# 2024-07-29  3040.199951
# 2024-07-30  3026.300049
# 2024-07-31  3010.850098
#
# [2363 rows x 1 columns]

# %%
close_price_reliance.plot(figsize=(16,8), fontsize=15, ylabel = 'Price Growth', title='Reliance Stock Price Growth')

plt.legend(fontsize=12, loc='upper left')
plt.show()

# %%
my_data = yf.Ticker('RELIANCE.NS')
df = my_data.history(period='3mo')

df.to_csv('/content/Reliance_100d_DATA.csv')
df = pd.read_csv('/content/Reliance_100d_DATA.csv')
df['Date'] = pd.to_datetime(df['Date'])


candlestick = go.Candlestick(x=df['Date'],
                             open=df['Open'],
                             high=df['High'],
                             low=df['Low'],
                             close=df['Close'],
                             name='Candlestick',
                             increasing_line_color='green',
                             decreasing_line_color='red',
                             increasing_fillcolor='lightgreen',
                             decreasing_fillcolor='salmon')
df['MA20'] = df['Close'].rolling(window=20).mean()
df['MA50'] = df['Close'].rolling(window=50).mean()
ma20 = go.Scatter(x=df['Date'], y=df['MA20'], mode='lines', name='MA 20', line=dict(color='blue', width=1.5))
ma50 = go.Scatter(x=df['Date'], y=df['MA50'], mode='lines', name='MA 50', line=dict(color='orange', width=1.5))

fig = go.Figure(data=[candlestick, ma20, ma50])
fig.update_layout(title='Reliance Stock Price Candlestick Chart with Moving Averages',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=False,
                  template='plotly_dark')

fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %% [markdown]
#   Indian IT Stocks

# %%
import yfinance as yf
stock_list_india = ["RELIANCE.NS", "HDFCBANK.NS", "WIPRO.NS", "INFY.NS", "SBIN.NS"]
stocks_list_india_load = yf.download(stock_list_india)
stocks_list_india_load.head()
# Out:
# [*********************100%%**********************]  5 of 5 completed
# Price        Adj Close                                                  Close  \
# Ticker     HDFCBANK.NS   INFY.NS RELIANCE.NS    SBIN.NS  WIPRO.NS HDFCBANK.NS
# Date
# 1996-01-01    2.331029  0.516419    9.270976  12.205255  0.908191       2.980
# 1996-01-02    2.327118  0.514330    9.198881  11.816772  0.837554       2.975
# 1996-01-03    2.334940  0.517811    9.268724  11.501693  0.867827       2.985
# 1996-01-04    2.319297  0.514393    9.183110  11.461926  0.867827       2.965
# 1996-01-05    2.315385  0.508316    9.120028  11.397690  0.867827       2.960
#
# Price                                                 ...        Open  \
# Ticker       INFY.NS RELIANCE.NS    SBIN.NS WIPRO.NS  ... HDFCBANK.NS
# Date                                                  ...
# 1996-01-01  0.796679   14.691803  18.823240   1.1250  ...       3.030
# 1996-01-02  0.793457   14.577553  18.224106   1.0375  ...       2.980
# ...

# %%
close_price_indstocks = stocks_list_india_load['Close']

# Plot the data
plt.figure(figsize=(16, 8))
close_price_indstocks.plot(kind='area', alpha=0.4, colormap='viridis')

plt.title('Top 5 Indian Stocks Price Growth (Area Plot)', fontsize=18)
plt.xlabel('Date', fontsize=15)
plt.ylabel('Price Growth', fontsize=15)
plt.legend(fontsize=12, loc='upper left')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)

plt.show()

# %%
close_price_indstocks
# Out:
# Ticker       HCLTECH.NS      INFY.NS      LTIM.NS       TCS.NS    WIPRO.NS
# Date
# 2016-07-21   361.774994   539.950012   697.599976  1253.025024  203.250046
# 2016-07-22   364.600006   536.224976   700.000000  1257.550049  201.656296
# 2016-07-25   370.200012   540.424988   693.049988  1279.474976  203.568802
# 2016-07-26   372.625000   544.349976   692.150024  1276.300049  204.787552
# 2016-07-27   376.750000   542.674988   689.900024  1288.775024  205.931305
# ...                 ...          ...          ...          ...         ...
# 2024-08-19  1678.500000  1864.800049  5676.100098  4490.000000  519.750000
# 2024-08-20  1686.750000  1872.199951  5707.799805  4523.299805  524.650024
# 2024-08-21  1677.250000  1872.699951  5713.450195  4551.500000  526.349976
# 2024-08-22  1676.150024  1880.250000  5704.399902  4502.000000  519.000000
# 2024-08-23  1661.449951  1862.099976  5641.600098  4463.899902  512.400024
#
# [1997 rows x 5 columns]

# %%
close_price_indstocks = stocks_list_india_load['Close'].copy()
close_price_indstocks.rename(columns={
    'RELIANCE.NS': 'RELIANCE',
    'HDFCBANK.NS': 'HDFCBANK',
    'WIPRO.NS': 'WIPRO',
    'INFY.NS': 'INFY',
    'SBIN.NS': 'SBIN'
}, inplace=True)

# %%
close_price_indstocks
# Out:
# Ticker          HCLTECH         INFY         LTIM          TCS       WIPRO
# Date
# 2016-07-21   361.774994   539.950012   697.599976  1253.025024  203.250046
# 2016-07-22   364.600006   536.224976   700.000000  1257.550049  201.656296
# 2016-07-25   370.200012   540.424988   693.049988  1279.474976  203.568802
# 2016-07-26   372.625000   544.349976   692.150024  1276.300049  204.787552
# 2016-07-27   376.750000   542.674988   689.900024  1288.775024  205.931305
# ...                 ...          ...          ...          ...         ...
# 2024-08-19  1678.500000  1864.800049  5676.100098  4490.000000  519.750000
# 2024-08-20  1686.750000  1872.199951  5707.799805  4523.299805  524.650024
# 2024-08-21  1677.250000  1872.699951  5713.450195  4551.500000  526.349976
# 2024-08-22  1676.150024  1880.250000  5704.399902  4502.000000  519.000000
# 2024-08-23  1661.449951  1862.099976  5641.600098  4463.899902  512.400024
#
# [1997 rows x 5 columns]

# %%
comparision = close_price_indstocks.iloc[0,0]
comparision
# Out:
# 2.9800000190734863

# %%
close_price_indstocks.RELIANCE
# Out:
# Date
# 1996-01-01      14.691803
# 1996-01-02      14.577553
# 1996-01-03      14.688232
# 1996-01-04      14.552561
# 1996-01-05      14.452592
#                  ...
# 2024-08-19    2976.800049
# 2024-08-20    2991.899902
# 2024-08-21    2997.350098
# 2024-08-22    2996.250000
# 2024-08-23    2999.949951
# Name: RELIANCE, Length: 7196, dtype: float64

# %%
comp_div = close_price_indstocks.RELIANCE.div(comparision)
comp_div
# Out:
# Date
# 1996-01-01       4.930135
# 1996-01-02       4.891796
# 1996-01-03       4.928937
# 1996-01-04       4.883410
# 1996-01-05       4.849863
#                  ...
# 2024-08-19     998.926184
# 2024-08-20    1003.993249
# 2024-08-21    1005.822174
# 2024-08-22    1005.453014
# 2024-08-23    1006.694608
# Name: RELIANCE, Length: 7196, dtype: float64

# %%
comp_mul = comp_div.mul(100)
comp_mul
# Out:
# Date
# 1996-01-01       493.013520
# 1996-01-02       489.179621
# 1996-01-03       492.893702
# 1996-01-04       488.340964
# 1996-01-05       484.986302
#                   ...
# 2024-08-19     99892.618449
# 2024-08-20    100399.324939
# 2024-08-21    100582.217398
# 2024-08-22    100545.301370
# 2024-08-23    100669.460804
# Name: RELIANCE, Length: 7196, dtype: float64

# %%
close_price_indstocks.iloc[0]
# Out:
# Ticker
# HDFCBANK     2.980000
# INFY         0.796679
# RELIANCE    14.691803
# SBIN        18.823240
# WIPRO        1.125000
# Name: 1996-01-01 00:00:00, dtype: float64

# %% [markdown]
# Performance change with same floor after 1996-01-01

# %%
close_price_indstocks.div(close_price_indstocks.iloc[0]).mul(100)
# Out:
# Ticker          HDFCBANK           INFY      RELIANCE         SBIN  \
# Date
# 1996-01-01    100.000000     100.000000    100.000000   100.000000
# 1996-01-02     99.832211      99.595565     99.222354    96.817049
# 1996-01-03    100.167781     100.269743     99.975697    94.235590
# 1996-01-04     99.496641      99.607745     99.052246    93.909776
# 1996-01-05     99.328860      98.430981     98.371806    93.383460
# ...                  ...            ...           ...          ...
# 2024-08-19  54750.001288  234071.690377  20261.638774  4322.847714
# 2024-08-20  54956.373849  235000.534009  20364.416176  4357.910623
# 2024-08-21  54557.048269  235063.294543  20401.513021  4332.675861
# 2024-08-22  54741.612026  236010.984721  20394.025188  4357.910623
# 2024-08-23  54531.880484  233732.774305  20419.208967  4331.613279
#
# Ticker             WIPRO
# Date
# 1996-01-01    100.000000
# 1996-01-02     92.222224
# 1996-01-03     95.555560
# 1996-01-04     95.555560
# ...

# %%
normclose = close_price_indstocks.div(close_price_indstocks.iloc[0]).mul(100)

normclose.plot(figsize=(15,8), fontsize=12, ylabel = 'Growth', title='Top 5 IT Stocks Price Growth from the same level')
plt.legend(fontsize=12, loc='upper left')
plt.show()

# %% [markdown]
# Calculate % Change of Price Change

# %%
del HDFCBANK["Lag1"]
del HDFCBANK["Diff"]

HDFCBANK
# Out:
#                HDFCBANK    Change
# Date
# 1996-01-01     2.980000       NaN
# 1996-01-02     2.975000 -0.167789
# 1996-01-03     2.985000  0.336134
# 1996-01-04     2.965000 -0.670016
# 1996-01-05     2.960000 -0.168630
# ...                 ...       ...
# 2024-08-19  1631.550049 -0.033694
# 2024-08-20  1637.699951  0.376936
# 2024-08-21  1625.800049 -0.726623
# 2024-08-22  1631.300049  0.338295
# 2024-08-23  1625.050049 -0.383130
#
# [7196 rows x 2 columns]

# %%
HDFCBANK.rename(columns={'% Change':'Change'}, inplace=True)
HDFCBANK
# Out:
#                HDFCBANK    Change
# Date
# 1996-01-01     2.980000       NaN
# 1996-01-02     2.975000 -0.167789
# 1996-01-03     2.985000  0.336134
# 1996-01-04     2.965000 -0.670016
# 1996-01-05     2.960000 -0.168630
# ...                 ...       ...
# 2024-08-19  1631.550049 -0.033694
# 2024-08-20  1637.699951  0.376936
# 2024-08-21  1625.800049 -0.726623
# 2024-08-22  1631.300049  0.338295
# 2024-08-23  1625.050049 -0.383130
#
# [7196 rows x 2 columns]

# %%
HDFCBANK.HDFCBANK.resample("M").last()
# Out:
# Date
# 1996-01-31       2.590000
# 1996-02-29       3.065000
# 1996-03-31       3.245000
# 1996-04-30       3.545000
# 1996-05-31       3.415000
#                  ...
# 2024-04-30    1520.099976
# 2024-05-31    1531.550049
# 2024-06-30    1683.800049
# 2024-07-31    1615.750000
# 2024-08-31    1625.050049
# Freq: M, Name: HDFCBANK, Length: 344, dtype: float64

# %%
HDFCBANK.HDFCBANK.resample("BM").last()
# Out:
# Date
# 1996-01-31       2.590000
# 1996-02-29       3.065000
# 1996-03-29       3.245000
# 1996-04-30       3.545000
# 1996-05-31       3.415000
#                  ...
# 2024-04-30    1520.099976
# 2024-05-31    1531.550049
# 2024-06-28    1683.800049
# 2024-07-31    1615.750000
# 2024-08-30    1625.050049
# Freq: BM, Name: HDFCBANK, Length: 344, dtype: float64

# %%
HDFCBANK.HDFCBANK.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 1996-01-31          NaN
# 1996-02-29    18.339774
# 1996-03-29     5.872751
# 1996-04-30     9.244998
# 1996-05-31    -3.667140
#                 ...
# 2024-04-30     4.986529
# 2024-05-31     0.753245
# 2024-06-28     9.940909
# 2024-07-31    -4.041457
# 2024-08-30     0.575587
# Freq: BM, Name: HDFCBANK, Length: 344, dtype: float64

# %% [markdown]
# Risk Measurement (Mean, Median and Standard Deviation)

# %%
HDFCBANK
# Out:
#                HDFCBANK    Change
# Date
# 1996-01-01     2.980000       NaN
# 1996-01-02     2.975000 -0.167789
# 1996-01-03     2.985000  0.336134
# 1996-01-04     2.965000 -0.670016
# 1996-01-05     2.960000 -0.168630
# ...                 ...       ...
# 2024-08-19  1631.550049 -0.033694
# 2024-08-20  1637.699951  0.376936
# 2024-08-21  1625.800049 -0.726623
# 2024-08-22  1631.300049  0.338295
# 2024-08-23  1625.050049 -0.383130
#
# [7196 rows x 2 columns]

# %%
del HDFCBANK["Change"]
HDFCBANK
# Out:
#                HDFCBANK
# Date
# 1996-01-01     2.980000
# 1996-01-02     2.975000
# 1996-01-03     2.985000
# 1996-01-04     2.965000
# 1996-01-05     2.960000
# ...                 ...
# 2024-08-19  1631.550049
# 2024-08-20  1637.699951
# 2024-08-21  1625.800049
# 2024-08-22  1631.300049
# 2024-08-23  1625.050049
#
# [7196 rows x 1 columns]

# %%
ret =HDFCBANK.pct_change().dropna()
ret
# Out:
#             HDFCBANK
# Date
# 1996-01-02 -0.001678
# 1996-01-03  0.003361
# 1996-01-04 -0.006700
# 1996-01-05 -0.001686
# 1996-01-08 -0.011824
# ...              ...
# 2024-08-19 -0.000337
# 2024-08-20  0.003769
# 2024-08-21 -0.007266
# 2024-08-22  0.003383
# 2024-08-23 -0.003831
#
# [7195 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7195 entries, 1996-01-02 to 2024-08-23
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   HDFCBANK  7195 non-null   float64
# dtypes: float64(1)
# memory usage: 112.4 KB

# %%
ret.plot(kind='hist', figsize=(12,8), bins=100)
plt.show()

# %% [markdown]
# Mean Return

# %%
daily_mean_ret = ret.mean()
daily_mean_ret
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:49: RuntimeWarning:
#
# invalid value encountered in reduce
# LTIM    0.001261
# Lag1    0.001268
# Diff         NaN
# dtype: float64

# %% [markdown]
# Median Return

# %%
daily_median_ret = ret.median()
daily_median_ret
# Out:
# HDFCBANK    0.0
# dtype: float64

# %% [markdown]
# Variance

# %%
var_daily = ret.var()
var_daily
# Out:
# HDFCBANK    0.000443
# dtype: float64

# %% [markdown]
# Standard Deviation

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# HDFCBANK    0.021045
# dtype: float64

# %%
annual_mean_ret = daily_mean_ret*252
annual_mean_ret
# Out:
# LTIM    0.317739
# Lag1    0.319565
# Diff         NaN
# dtype: float64

# %%
annual_var_ret = var_daily*252
annual_var_ret
# Out:
# HDFCBANK    0.11161
# dtype: float64

# %% [markdown]
# # Analysing 10 Stocks
# This involves analyzing historical stock data for a selected group of major technology and entertainment companies. The dataset includes stock prices from January 1, 2013, to the present, for the following companies:
#
# 1. Apple Inc. (AAPL)
# 2. Alphabet Inc. (GOOGL)
# 3. Amazon.com Inc. (AMZN)
# 4. Microsoft Corp. (MSFT)
# 5. Tesla Inc. (TSLA)
# 6. Meta Platforms Inc. (META)
# 7. NVIDIA Corporation (NVDA)
# 8. Netflix Inc. (NFLX)
# 9. The Walt Disney Company (DIS)
# 10. Johnson & Johnson (JNJ)

# %%
ticker = [
    "AAPL",
    "GOOGL",
    "AMZN",
    "MSFT",
    "TSLA",
    "META",
    "NVDA",
    "NFLX",
    "DIS",
    "JNJ"
]
stocks = yf.download(ticker, start="2013-01-01", end=None)
stocks
# Out:
# [*********************100%%**********************]  10 of 10 completed
# Price        Adj Close                                                 \
# Ticker            AAPL        AMZN        DIS       GOOGL         JNJ
# Date
# 2013-01-02   16.705696   12.865500  46.091099   18.078600   51.558193
# 2013-01-03   16.494841   12.924000  46.190315   18.089098   51.485413
# 2013-01-04   16.035381   12.957500  47.074245   18.446547   52.074963
# 2013-01-07   15.941058   13.423000  45.973843   18.366058   51.965771
# 2013-01-08   15.983955   13.319000  45.784420   18.329815   51.973061
# ...                ...         ...        ...         ...         ...
# 2024-08-19  225.889999  178.220001  90.820000  166.669998  159.630005
# 2024-08-20  226.509995  178.880005  89.739998  167.179993  160.160004
# 2024-08-21  226.399994  180.110001  90.720001  165.850006  161.429993
# 2024-08-22  224.529999  176.130005  89.919998  163.800003  162.350006
# ...

# %%
close = stocks.loc[:, "Close"].copy()

normclose = close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8), fontsize=12, ylabel = 'Growth', title="Nifty50's top 10 Stocks Growth")
plt.legend(fontsize=12, loc='upper left')
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL      AMZN       DIS     GOOGL       JNJ      META  \
# Date
# 2013-01-03 -0.012622  0.004547  0.002153  0.000581 -0.001412 -0.008214
# 2013-01-04 -0.027855  0.002592  0.019137  0.019760  0.011450  0.035650
# 2013-01-07 -0.005882  0.035925 -0.023376 -0.004363 -0.002096  0.022949
# 2013-01-08  0.002691 -0.007748 -0.004120 -0.001973  0.000140 -0.012237
# 2013-01-09 -0.015629 -0.000113  0.000394  0.006573  0.004481  0.052650
#
# Ticker          MSFT      NFLX      NVDA      TSLA
# Date
# 2013-01-03 -0.013396  0.049777  0.000786 -0.016685
# 2013-01-04 -0.018716 -0.006315  0.032993 -0.010642
# 2013-01-07 -0.001870  0.033549 -0.028897 -0.001744
# 2013-01-08 -0.005245 -0.020565 -0.021926 -0.019220
# 2013-01-09  0.005650 -0.012865 -0.022418 -0.001187

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2930.0  0.000994  0.017760 -0.128647 -0.007454  0.000892  0.010144
# AMZN    2930.0  0.001103  0.020404 -0.140494 -0.008617  0.001050  0.011363
# DIS     2930.0  0.000336  0.016742 -0.131632 -0.006886  0.000304  0.008005
# GOOGL   2930.0  0.000904  0.017281 -0.116341 -0.007179  0.001002  0.009262
# JNJ     2930.0  0.000347  0.011055 -0.100379 -0.004797  0.000361  0.005929
# META    2930.0  0.001296  0.024244 -0.263901 -0.009577  0.001091  0.012687
# MSFT    2930.0  0.001066  0.016715 -0.147390 -0.006686  0.000830  0.009543
# NFLX    2930.0  0.001770  0.029062 -0.351166 -0.011614  0.000544  0.014530
# NVDA    2930.0  0.002456  0.028635 -0.187559 -0.011035  0.002110  0.015731
# TSLA    2930.0  0.002190  0.035892 -0.210628 -0.015570  0.001361  0.019080
#
#              max
# Ticker
# AAPL    0.119808
# AMZN    0.141311
# DIS     0.144123
# GOOGL   0.162584
# JNJ     0.079977
# ...

# %%
summary = ret.describe().T.loc[:,["mean", "std"]]   # to display only two columns specific
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.000994  0.017760
# AMZN    0.001103  0.020404
# DIS     0.000336  0.016742
# GOOGL   0.000904  0.017281
# JNJ     0.000347  0.011055
# META    0.001296  0.024244
# MSFT    0.001066  0.016715
# NFLX    0.001770  0.029062
# NVDA    0.002456  0.028635
# TSLA    0.002190  0.035892

# %% [markdown]
# Risk vs Return Analysis

# %%
summary["mean"]=summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#               mean       std
# Ticker
# AAPL     63.096721  4.475492
# AMZN     70.021203  5.141782
# DIS      21.322212  4.218968
# GOOGL    57.439319  4.354868
# JNJ      22.054462  2.785967
# META     82.330621  6.109543
# MSFT     67.668351  4.212248
# NFLX    112.378891  7.323516
# NVDA    155.938958  7.216014
# TSLA    139.054982  9.044664

# %%
summary.plot.scatter(x="std", y="mean", figsize=(16,10), s=50, fontsize=15)
for i in summary.index:
    # Annotate the point *xy* with text *text*.
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002, summary.loc[i, "mean"]+0.002),size=12)  # 0.002 for text alignment

plt.xlabel("Annual risk(std)", fontsize=15)
plt.ylabel("Annual return(std)", fontsize=15)
plt.title("Risk/Return", fontsize=25)
plt.show()

# %% [markdown]
# Co-variance and Co-relations

# %%
ret.cov()
# Out:
# Ticker      AAPL      AMZN       DIS     GOOGL       JNJ      META      MSFT  \
# Ticker
# AAPL    0.000315  0.000178  0.000116  0.000170  0.000063  0.000200  0.000182
# AMZN    0.000178  0.000416  0.000128  0.000219  0.000053  0.000271  0.000204
# DIS     0.000116  0.000128  0.000280  0.000124  0.000057  0.000139  0.000122
# GOOGL   0.000170  0.000219  0.000124  0.000299  0.000063  0.000244  0.000195
# JNJ     0.000063  0.000053  0.000057  0.000063  0.000122  0.000058  0.000069
# META    0.000200  0.000271  0.000139  0.000244  0.000058  0.000588  0.000208
# MSFT    0.000182  0.000204  0.000122  0.000195  0.000069  0.000208  0.000279
# NFLX    0.000165  0.000277  0.000139  0.000209  0.000049  0.000281  0.000193
# NVDA    0.000258  0.000285  0.000169  0.000256  0.000058  0.000311  0.000275
# TSLA    0.000239  0.000268  0.000170  0.000215  0.000047  0.000266  0.000219
#
# Ticker      NFLX      NVDA      TSLA
# Ticker
# AAPL    0.000165  0.000258  0.000239
# ...

# %%
ret.corr()
# Out:
# Ticker      AAPL      AMZN       DIS     GOOGL       JNJ      META      MSFT  \
# Ticker
# AAPL    1.000000  0.492210  0.388988  0.555129  0.323235  0.465037  0.613282
# AMZN    0.492210  1.000000  0.373314  0.621023  0.235572  0.548606  0.596793
# DIS     0.388988  0.373314  1.000000  0.428430  0.308542  0.343363  0.436590
# GOOGL   0.555129  0.621023  0.428430  1.000000  0.327223  0.582849  0.674226
# JNJ     0.323235  0.235572  0.308542  0.327223  1.000000  0.214679  0.373617
# META    0.465037  0.548606  0.343363  0.582849  0.214679  1.000000  0.512857
# MSFT    0.613282  0.596793  0.436590  0.674226  0.373617  0.512857  1.000000
# NFLX    0.319429  0.467966  0.285455  0.415321  0.151487  0.399065  0.397728
# NVDA    0.507692  0.487694  0.352437  0.518167  0.183808  0.447421  0.575055
# TSLA    0.374799  0.365978  0.283646  0.347164  0.118912  0.305174  0.365212
#
# Ticker      NFLX      NVDA      TSLA
# Ticker
# AAPL    0.319429  0.507692  0.374799
# ...

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap="Reds", annot=True, annot_kws={"size":15},vmax=0.6)
plt.show()

# %% [markdown]
# Simple Return vs Compound return vs Log Return

# %%
df = pd.DataFrame(index=[2021,2022,2023], data=[100,50,95], columns = ["Price"] )
df
# Out:
#       Price
# 2021    100
# 2022     50
# 2023     95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2022   -0.5
# 2023    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2022 -0.693147
# 2023  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %% [markdown]
# Rolling Return

# %%
TataMotors = yf.download("TATAMOTORS.NS")
TataMotors = TataMotors.Close.to_frame()
TataMotors
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Close
# Date
# 1991-01-02    21.857864
# 1991-01-03    21.857864
# 1991-01-04    21.857864
# 1991-01-07    21.109308
# 1991-01-08    21.109308
# ...                 ...
# 2024-08-19  1087.699951
# 2024-08-20  1086.900024
# 2024-08-21  1085.199951
# 2024-08-22  1068.449951
# 2024-08-23  1085.150024
#
# [8499 rows x 1 columns]

# %%
TataMotors_roll =TataMotors.rolling(window=10)

TataMotors_roll =TataMotors_roll.mean()

TataMotors_roll.head(15)
# Out:
#                 Close
# Date
# 1991-01-02        NaN
# 1991-01-03        NaN
# 1991-01-04        NaN
# 1991-01-07        NaN
# 1991-01-08        NaN
# 1991-01-09        NaN
# 1991-01-10        NaN
# 1991-01-11        NaN
# 1991-01-14        NaN
# 1991-01-15  21.049423
# 1991-01-16  20.899712
# 1991-01-17  20.750000
# 1991-01-18  20.600289
# 1991-01-21  20.525433
# 1991-01-22  20.450577

# %%
TataMotors.rolling(window=10).median()
# Out:
#                   Close
# Date
# 1991-01-02          NaN
# 1991-01-03          NaN
# 1991-01-04          NaN
# 1991-01-07          NaN
# 1991-01-08          NaN
# ...                 ...
# 2024-08-19  1057.899963
# 2024-08-20  1065.224976
# 2024-08-21  1072.125000
# 2024-08-22  1072.299988
# 2024-08-23  1080.650024
#
# [8499 rows x 1 columns]

# %%
TataMotors.rolling(window=10).max()
# Out:
#                   Close
# Date
# 1991-01-02          NaN
# 1991-01-03          NaN
# 1991-01-04          NaN
# 1991-01-07          NaN
# 1991-01-08          NaN
# ...                 ...
# 2024-08-19  1098.349976
# 2024-08-20  1098.349976
# 2024-08-21  1098.349976
# 2024-08-22  1098.349976
# 2024-08-23  1098.349976
#
# [8499 rows x 1 columns]

# %%
TataMotors.rolling(window=10, min_periods=5).min().head(15)
# Out:
#                 Close
# Date
# 1991-01-02        NaN
# 1991-01-03        NaN
# 1991-01-04        NaN
# 1991-01-07        NaN
# 1991-01-08  21.109308
# 1991-01-09  20.510462
# 1991-01-10  20.510462
# 1991-01-11  20.510462
# 1991-01-14  20.360750
# 1991-01-15  20.360750
# 1991-01-16  20.360750
# 1991-01-17  20.360750
# 1991-01-18  20.360750
# 1991-01-21  20.360750
# 1991-01-22  20.360750

# %%
print(type(TataMotors))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 50 Days Moving Average

# %%
TataMotors['SMA50'] = TataMotors['Close'].rolling(window=50, min_periods=50).mean()

# %%
plt.figure(figsize=(12, 8))
TataMotors.plot(
    kind='line',
    color='green',
    linestyle='-',
    linewidth=2,
    marker='o',
    markersize=5,
    markerfacecolor='red',
    markeredgewidth=2
)

plt.title("Tata Motors Stock Price", fontsize=18, fontweight='bold', color='darkblue')
plt.xlabel("Date", fontsize=15, fontweight='bold')
plt.ylabel("Close Price", fontsize=15, fontweight='bold')

plt.legend(loc="upper left", fontsize=15)

plt.grid(True, linestyle='--', color='gray', alpha=0.5)

plt.show()

# %% [markdown]
# 200 Days moving Average

# %%
TataMotors["SMA200"] =TataMotors.Close.rolling(window=200, min_periods=200).mean()

plt.figure(figsize=(12, 8))
TataMotors.plot(
    color=['blue', 'orange'],
    linestyle='-',
    linewidth=2,
    marker='o',
    markersize=5,
    markerfacecolor='red',
    markeredgewidth=2,
    alpha=0.8
)

plt.title("Tata Motors Stock Price and 200-Day SMA", fontsize=18, fontweight='bold', color='darkblue')
plt.xlabel("Date", fontsize=15, fontweight='bold')
plt.ylabel("Price", fontsize=15, fontweight='bold')

plt.legend(loc="upper left", fontsize=15)

plt.grid(True, linestyle='--', color='gray', alpha=0.5)

plt.show()

# %% [markdown]
# Exponential Moving Average (EMA)

# %%
TataMotors["EMA100"] =TataMotors.Close.ewm(span=100, min_periods=100).mean()


TataMotors.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
TataMotors["Day"] =TataMotors.index.day_name()

TataMotors
# Out:
#                   Close      SMA200      EMA100        Day  Quarter  \
# Date
# 1991-01-02    21.857864         NaN         NaN  Wednesday        1
# 1991-01-03    21.857864         NaN         NaN   Thursday        1
# 1991-01-04    21.857864         NaN         NaN     Friday        1
# 1991-01-07    21.109308         NaN         NaN     Monday        1
# 1991-01-08    21.109308         NaN         NaN    Tuesday        1
# ...                 ...         ...         ...        ...      ...
# 2024-08-19  1087.699951  900.769001  992.479966     Monday        3
# 2024-08-20  1086.900024  902.966751  994.349670    Tuesday        3
# 2024-08-21  1085.199951  905.203501  996.148686  Wednesday        3
# 2024-08-22  1068.449951  907.413000  997.580394   Thursday        3
# 2024-08-23  1085.150024  909.633501  999.314446     Friday        3
#
#                   SMA50
# Date
# 1991-01-02          NaN
# 1991-01-03          NaN
# 1991-01-04          NaN
# 1991-01-07          NaN
# ...

# %%
TataMotors["Quarter"] =TataMotors.index.quarter
TataMotors
# Out:
#                   Close      SMA200      EMA100        Day  Quarter  \
# Date
# 1991-01-02    21.857864         NaN         NaN  Wednesday        1
# 1991-01-03    21.857864         NaN         NaN   Thursday        1
# 1991-01-04    21.857864         NaN         NaN     Friday        1
# 1991-01-07    21.109308         NaN         NaN     Monday        1
# 1991-01-08    21.109308         NaN         NaN    Tuesday        1
# ...                 ...         ...         ...        ...      ...
# 2024-08-19  1087.699951  900.769001  992.479966     Monday        3
# 2024-08-20  1086.900024  902.966751  994.349670    Tuesday        3
# 2024-08-21  1085.199951  905.203501  996.148686  Wednesday        3
# 2024-08-22  1068.449951  907.413000  997.580394   Thursday        3
# 2024-08-23  1085.150024  909.633501  999.314446     Friday        3
#
#                   SMA50
# Date
# 1991-01-02          NaN
# 1991-01-03          NaN
# 1991-01-04          NaN
# 1991-01-07          NaN
# ...

# %% [markdown]
# Varun Bevarages Ltd (VBL) Analysis

# %%
VBL = yf.download('VBL.NS')

VBL = VBL.Close.to_frame()
VBL
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Close
# Date
# 2016-11-08    68.074074
# 2016-11-09    64.348145
# 2016-11-10    64.644447
# 2016-11-11    65.281479
# 2016-11-15    64.903702
# ...                 ...
# 2024-08-19  1508.400024
# 2024-08-20  1491.599976
# 2024-08-21  1546.099976
# 2024-08-22  1594.199951
# 2024-08-23  1582.099976
#
# [1925 rows x 1 columns]

# %%
all_days = pd.date_range(start="2013-12-31", end="2024-08-01",freq="D")
all_days
# Out:
# DatetimeIndex(['2013-12-31', '2014-01-01', '2014-01-02', '2014-01-03',
#                '2014-01-04', '2014-01-05', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09',
#                ...
#                '2024-07-23', '2024-07-24', '2024-07-25', '2024-07-26',
#                '2024-07-27', '2024-07-28', '2024-07-29', '2024-07-30',
#                '2024-07-31', '2024-08-01'],
#               dtype='datetime64[ns]', length=3867, freq='D')

# %%
VBL = VBL.reindex(all_days)
VBL
# Out:
#                   Close
# 2013-12-31          NaN
# 2014-01-01          NaN
# 2014-01-02          NaN
# 2014-01-03          NaN
# 2014-01-04          NaN
# ...                 ...
# 2024-07-28          NaN
# 2024-07-29  1685.300049
# 2024-07-30  1577.400024
# 2024-07-31  1577.400024
# 2024-08-01  1575.750000
#
# [3867 rows x 1 columns]

# %%
VBL.fillna(method="ffill")
# Out:
# <ipython-input-421-6b540e1ae5a2>:1: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#                   Close
# 2013-12-31          NaN
# 2014-01-01          NaN
# 2014-01-02          NaN
# 2014-01-03          NaN
# 2014-01-04          NaN
# ...                 ...
# 2024-07-28  1676.650024
# 2024-07-29  1685.300049
# 2024-07-30  1577.400024
# 2024-07-31  1577.400024
# 2024-08-01  1575.750000
#
# [3867 rows x 1 columns]

# %%
VBL = yf.download("VBL.NS", interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
VBL
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2016-11-07    63.703705    69.888885    58.222221    65.281479    62.219921
# 2016-11-14    65.281479    66.222221    63.703705    65.259262    62.198742
# 2016-11-21    64.000000    65.925926    64.000000    64.659256    61.626888
# 2016-11-28    65.185188    65.400002    62.970371    64.014816    61.012669
# 2016-12-05    63.733334    64.592590    60.370369    61.511112    58.626381
# ...                 ...          ...          ...          ...          ...
# 2024-07-22  1560.000000  1693.000000  1507.750000  1676.650024  1675.243042
# 2024-07-29  1698.000000  1702.800049  1552.449951  1572.349976  1571.030518
# 2024-08-05  1539.500000  1549.500000  1455.000000  1508.599976  1507.333984
# 2024-08-12  1495.000000  1502.949951  1412.500000  1421.849976  1421.849976
# 2024-08-19  1429.000000  1609.449951  1417.949951  1582.099976  1582.099976
#
#                Volume
# Date
# ...

# %% [markdown]
# Cumulative Return

# %%
VBL = yf.download("VBL.NS")
VBL = VBL.Close.to_frame()
VBL
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Close
# Date
# 2016-11-08    68.074074
# 2016-11-09    64.348145
# 2016-11-10    64.644447
# 2016-11-11    65.281479
# 2016-11-15    64.903702
# ...                 ...
# 2024-08-19  1508.400024
# 2024-08-20  1491.599976
# 2024-08-21  1546.099976
# 2024-08-22  1594.199951
# 2024-08-23  1582.099976
#
# [1925 rows x 1 columns]

# %%
VBL["day_change"] = np.log(VBL.div(VBL.shift(1)))
VBL.dropna(inplace=True)
VBL
# Out:
#                   Close  day_change
# Date
# 2016-11-09    64.348145   -0.056288
# 2016-11-10    64.644447    0.004594
# 2016-11-11    65.281479    0.009806
# 2016-11-15    64.903702   -0.005804
# 2016-11-16    64.548149   -0.005493
# ...                 ...         ...
# 2024-08-19  1508.400024    0.059091
# 2024-08-20  1491.599976   -0.011200
# 2024-08-21  1546.099976    0.035886
# 2024-08-22  1594.199951    0.030636
# 2024-08-23  1582.099976   -0.007619
#
# [1924 rows x 2 columns]

# %%
VBL.day_change.sum()
# Out:
# 3.1459119092632064

# %%
np.exp(VBL.day_change.sum())
# Out:
# 23.24085936786393

# %%
VBL['Cumulative_Returns'] = VBL.day_change.cumsum().apply(np.exp)
VBL
# Out:
#                   Close  day_change  Cumulative_Returns
# Date
# 2016-11-09    64.348145   -0.056288            0.945267
# 2016-11-10    64.644447    0.004594            0.949619
# 2016-11-11    65.281479    0.009806            0.958977
# 2016-11-15    64.903702   -0.005804            0.953428
# 2016-11-16    64.548149   -0.005493            0.948205
# ...                 ...         ...                 ...
# 2024-08-19  1508.400024    0.059091           22.158216
# 2024-08-20  1491.599976   -0.011200           21.911425
# 2024-08-21  1546.099976    0.035886           22.712024
# 2024-08-22  1594.199951    0.030636           23.418607
# 2024-08-23  1582.099976   -0.007619           23.240859
#
# [1924 rows x 3 columns]

# %% [markdown]
# Buy and Hold Strategy

# %%
plt.figure(figsize=(12, 8))
VBL.Cumulative_Returns.plot(
    color='blue',
    linestyle='-',
    linewidth=2,
    marker='o',
    markersize=5,
    markerfacecolor='red',
    markeredgewidth=2,
    alpha=0.8
)

plt.title("VBL Buy and Hold", fontsize=18, fontweight='bold', color='darkblue')
plt.xlabel("Date", fontsize=15, fontweight='bold')
plt.ylabel("Cumulative Returns", fontsize=15, fontweight='bold')

plt.grid(True, linestyle='--', color='gray', alpha=0.5)

plt.show()

# %% [markdown]
# Annual Daily Return

# %%
VBL.day_change.mean()*252
# Out:
# 0.4120425161820832

# %% [markdown]
# Annual Standard Deviation

# %%
VBL.day_change.std()*np.sqrt(252)
# Out:
# 0.35055496409967996

# %% [markdown]
# Cumulative Maximum

# %%
VBL["CumulativeMax"] = VBL.Cumulative_Returns.cummax()
VBL
# Out:
#                   Close  day_change  Cumulative_Returns  CumulativeMax
# Date
# 2016-11-09    64.348145   -0.056288            0.945267       0.945267
# 2016-11-10    64.644447    0.004594            0.949619       0.949619
# 2016-11-11    65.281479    0.009806            0.958977       0.958977
# 2016-11-15    64.903702   -0.005804            0.953428       0.958977
# 2016-11-16    64.548149   -0.005493            0.948205       0.958977
# ...                 ...         ...                 ...            ...
# 2024-08-19  1508.400024    0.059091           22.158216      24.756856
# 2024-08-20  1491.599976   -0.011200           21.911425      24.756856
# 2024-08-21  1546.099976    0.035886           22.712024      24.756856
# 2024-08-22  1594.199951    0.030636           23.418607      24.756856
# 2024-08-23  1582.099976   -0.007619           23.240859      24.756856
#
# [1924 rows x 4 columns]

# %%
VBL[["Cumulative_Returns", "CumulativeMax"]].plot(figsize=(12,8), title="VBL Buy and Hold + CumulativeMax", fontsize=12)
plt.show()

# %%
VBL["drawdown"] = VBL['CumulativeMax']-VBL['Cumulative_Returns']
VBL
# Out:
#                   Close  day_change  Cumulative_Returns  CumulativeMax  \
# Date
# 2016-11-09    64.348145   -0.056288            0.945267       0.945267
# 2016-11-10    64.644447    0.004594            0.949619       0.949619
# 2016-11-11    65.281479    0.009806            0.958977       0.958977
# 2016-11-15    64.903702   -0.005804            0.953428       0.958977
# 2016-11-16    64.548149   -0.005493            0.948205       0.958977
# ...                 ...         ...                 ...            ...
# 2024-08-19  1508.400024    0.059091           22.158216      24.756856
# 2024-08-20  1491.599976   -0.011200           21.911425      24.756856
# 2024-08-21  1546.099976    0.035886           22.712024      24.756856
# 2024-08-22  1594.199951    0.030636           23.418607      24.756856
# 2024-08-23  1582.099976   -0.007619           23.240859      24.756856
#
#             drawdown
# Date
# 2016-11-09  0.000000
# 2016-11-10  0.000000
# 2016-11-11  0.000000
# ...

# %%
VBL.drawdown.max()
# Out:
# 3.870050058250886

# %%
VBL.drawdown.idxmax()
# Out:
# Timestamp('2024-08-16 00:00:00')

# %%
VBL.loc[(VBL.index=='2023-01-13')]
# Out:
#               Close  day_change  Cumulative_Returns  CumulativeMax  drawdown
# Date
# 2023-01-13  567.875    -0.04422            8.342016      10.385011  2.042995

# %%
VBL.loc[(VBL.index<='2023-01-13')]
# Out:
#                  Close  day_change  Cumulative_Returns  CumulativeMax  \
# Date
# 2016-11-09   64.348145   -0.056288            0.945267       0.945267
# 2016-11-10   64.644447    0.004594            0.949619       0.949619
# 2016-11-11   65.281479    0.009806            0.958977       0.958977
# 2016-11-15   64.903702   -0.005804            0.953428       0.958977
# 2016-11-16   64.548149   -0.005493            0.948205       0.958977
# ...                ...         ...                 ...            ...
# 2023-01-09  654.375000    0.006016            9.612690      10.385011
# 2023-01-10  643.650024   -0.016525            9.455142      10.385011
# 2023-01-11  612.525024   -0.049565            8.997919      10.385011
# 2023-01-12  593.549988   -0.031468            8.719178      10.385011
# 2023-01-13  567.875000   -0.044220            8.342016      10.385011
#
#             drawdown
# Date
# 2016-11-09  0.000000
# 2016-11-10  0.000000
# 2016-11-11  0.000000
# 2016-11-15  0.005550
# ...

# %%
VBL["drawdown%"] = (VBL['CumulativeMax']-VBL['Cumulative_Returns'])/VBL['CumulativeMax']
VBL
# Out:
#                   Close  day_change  Cumulative_Returns  CumulativeMax  \
# Date
# 2016-11-09    64.348145   -0.056288            0.945267       0.945267
# 2016-11-10    64.644447    0.004594            0.949619       0.949619
# 2016-11-11    65.281479    0.009806            0.958977       0.958977
# 2016-11-15    64.903702   -0.005804            0.953428       0.958977
# 2016-11-16    64.548149   -0.005493            0.948205       0.958977
# ...                 ...         ...                 ...            ...
# 2024-08-19  1508.400024    0.059091           22.158216      24.756856
# 2024-08-20  1491.599976   -0.011200           21.911425      24.756856
# 2024-08-21  1546.099976    0.035886           22.712024      24.756856
# 2024-08-22  1594.199951    0.030636           23.418607      24.756856
# 2024-08-23  1582.099976   -0.007619           23.240859      24.756856
#
#             drawdown  drawdown%
# Date
# 2016-11-09  0.000000   0.000000
# 2016-11-10  0.000000   0.000000
# ...

# %%
VBL['drawdown%'].max()
# Out:
# 0.37689771987949844

# %%
VBL['drawdown%'].idxmax()
# Out:
# Timestamp('2020-03-31 00:00:00')

# %%
VBL.loc[(VBL.index<='2020-03-31')]
# Out:
#                  Close  day_change  Cumulative_Returns  CumulativeMax  \
# Date
# 2016-11-09   64.348145   -0.056288            0.945267       0.945267
# 2016-11-10   64.644447    0.004594            0.949619       0.949619
# 2016-11-11   65.281479    0.009806            0.958977       0.958977
# 2016-11-15   64.903702   -0.005804            0.953428       0.958977
# 2016-11-16   64.548149   -0.005493            0.948205       0.958977
# ...                ...         ...                 ...            ...
# 2020-03-25  124.199997   -0.006243            1.824483       2.773776
# 2020-03-26  132.655548    0.065863            1.948694       2.773776
# 2020-03-27  126.011108   -0.051386            1.851088       2.773776
# 2020-03-30  117.822220   -0.067193            1.730794       2.773776
# 2020-03-31  117.655556   -0.001416            1.728346       2.773776
#
#             drawdown  drawdown%
# Date
# 2016-11-09  0.000000   0.000000
# 2016-11-10  0.000000   0.000000
# ...

# %%
VBL.loc[(VBL.index<='2020-03-31')]
# Out:
#                  Close  day_change  Cumulative_Returns  CumulativeMax  \
# Date
# 2016-11-09   64.348145   -0.056288            0.945267       0.945267
# 2016-11-10   64.644447    0.004594            0.949619       0.949619
# 2016-11-11   65.281479    0.009806            0.958977       0.958977
# 2016-11-15   64.903702   -0.005804            0.953428       0.958977
# 2016-11-16   64.548149   -0.005493            0.948205       0.958977
# ...                ...         ...                 ...            ...
# 2020-03-25  124.199997   -0.006243            1.824483       2.773776
# 2020-03-26  132.655548    0.065863            1.948694       2.773776
# 2020-03-27  126.011108   -0.051386            1.851088       2.773776
# 2020-03-30  117.822220   -0.067193            1.730794       2.773776
# 2020-03-31  117.655556   -0.001416            1.728346       2.773776
#
#             drawdown  drawdown%
# Date
# 2016-11-09  0.000000   0.000000
# 2016-11-10  0.000000   0.000000
# ...

# %% [markdown]
# ## SMA Strategy

# %%
data = VBL.Close.loc[(VBL.index>='2016-11-09')]
data = data.to_frame()
data
# Out:
#                   Close
# Date
# 2016-11-09    64.348145
# 2016-11-10    64.644447
# 2016-11-11    65.281479
# 2016-11-15    64.903702
# 2016-11-16    64.548149
# ...                 ...
# 2024-08-19  1508.400024
# 2024-08-20  1491.599976
# 2024-08-21  1546.099976
# 2024-08-22  1594.199951
# 2024-08-23  1582.099976
#
# [1924 rows x 1 columns]

# %% [markdown]
# 50D and 100D Moving Averages

# %%
sma_s = 50
sma_l = 100

data['sma_s'] = data.Close.rolling(sma_s).mean()
data['sma_l'] = data.Close.rolling(sma_l).mean()

data
# Out:
#                   Close        sma_s        sma_l
# Date
# 2016-11-09    64.348145          NaN          NaN
# 2016-11-10    64.644447          NaN          NaN
# 2016-11-11    65.281479          NaN          NaN
# 2016-11-15    64.903702          NaN          NaN
# 2016-11-16    64.548149          NaN          NaN
# ...                 ...          ...          ...
# 2024-08-19  1508.400024  1573.185002  1513.040005
# 2024-08-20  1491.599976  1573.029001  1513.954504
# 2024-08-21  1546.099976  1573.579001  1515.413004
# 2024-08-22  1594.199951  1574.542000  1517.331003
# 2024-08-23  1582.099976  1575.238999  1519.135004
#
# [1924 rows x 3 columns]

# %%
data.plot(figsize=(12,8), title="VBL - SMA{} | SMA{}".format(sma_s, sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'VBL - SMA50 | SMA100'}, xlabel='Date'>

# %% [markdown]
# On a specific Time Frame

# %%
data.loc['2023'].plot(figsize=(12,8), title="VBL - SMA{} | SMA{}".format(sma_s, sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'VBL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)
data
# Out:
#                   Close        sma_s        sma_l
# Date
# 2017-04-03    59.948147    57.447703    59.555852
# 2017-04-05    60.837036    57.446814    59.520740
# 2017-04-06    62.362961    57.495259    59.497926
# 2017-04-07    63.037037    57.580592    59.475481
# 2017-04-10    64.177780    57.664889    59.468222
# ...                 ...          ...          ...
# 2024-08-19  1508.400024  1573.185002  1513.040005
# 2024-08-20  1491.599976  1573.029001  1513.954504
# 2024-08-21  1546.099976  1573.579001  1515.413004
# 2024-08-22  1594.199951  1574.542000  1517.331003
# 2024-08-23  1582.099976  1575.238999  1519.135004
#
# [1825 rows x 3 columns]

# %%
data['Position'] = np.where(data['sma_s']> data['sma_l'],1,-1)
data
# Out:
#                   Close        sma_s        sma_l  Position
# Date
# 2017-04-03    59.948147    57.447703    59.555852        -1
# 2017-04-05    60.837036    57.446814    59.520740        -1
# 2017-04-06    62.362961    57.495259    59.497926        -1
# 2017-04-07    63.037037    57.580592    59.475481        -1
# 2017-04-10    64.177780    57.664889    59.468222        -1
# ...                 ...          ...          ...       ...
# 2024-08-19  1508.400024  1573.185002  1513.040005         1
# 2024-08-20  1491.599976  1573.029001  1513.954504         1
# 2024-08-21  1546.099976  1573.579001  1515.413004         1
# 2024-08-22  1594.199951  1574.542000  1517.331003         1
# 2024-08-23  1582.099976  1575.238999  1519.135004         1
#
# [1825 rows x 4 columns]

# %%
data.loc['2023', ['sma_s', 'sma_l', 'Position']].plot(figsize=(12,8), title="VBL - SMA{} | SMA{}".format(sma_s, sma_l), fontsize=12, secondary_y = 'Position' )
# Out:
# <Axes: title={'center': 'VBL - SMA50 | SMA100'}, xlabel='Date'>

# %% [markdown]
# Buy and Hold Strategy

# %%
data['returnsB&H'] = np.log(data.Close.div(data.Close.shift(1)))
data['strategy'] = data['returnsB&H']*data.Position.shift(1)
data.dropna(inplace=True)
data
# Out:
#                   Close        sma_s        sma_l  Position  returnsB&H  \
# Date
# 2017-04-05    60.837036    57.446814    59.520740        -1    0.014719
# 2017-04-06    62.362961    57.495259    59.497926        -1    0.024773
# 2017-04-07    63.037037    57.580592    59.475481        -1    0.010751
# 2017-04-10    64.177780    57.664889    59.468222        -1    0.017935
# 2017-04-11    64.466667    57.754666    59.467407        -1    0.004491
# ...                 ...          ...          ...       ...         ...
# 2024-08-19  1508.400024  1573.185002  1513.040005         1    0.059091
# 2024-08-20  1491.599976  1573.029001  1513.954504         1   -0.011200
# 2024-08-21  1546.099976  1573.579001  1515.413004         1    0.035886
# 2024-08-22  1594.199951  1574.542000  1517.331003         1    0.030636
# 2024-08-23  1582.099976  1575.238999  1519.135004         1   -0.007619
#
#             strategy
# Date
# 2017-04-05 -0.014719
# 2017-04-06 -0.024773
# 2017-04-07 -0.010751
# ...

# %%
data[['returnsB&H', 'strategy']].sum()
# Out:
# returnsB&H    3.273028
# strategy      0.781045
# dtype: float64

# %%
data[['returnsB&H', 'strategy']].sum().apply(np.exp)
# Out:
# returnsB&H    26.391141
# strategy       2.183753
# dtype: float64

# %%
data[['returnsB&H', 'strategy']].std()*np.sqrt(252)  #annual std
# Out:
# returnsB&H    0.354230
# strategy      0.355309
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Strategy adjusted with long bias

# %%
data['position2'] = np.where(data['sma_s']> data['sma_l'],1,0)
data['strategy2'] = data['returnsB&H']*data.position2.shift(1)
data.dropna(inplace=True)
data
# Out:
#                   Close        sma_s        sma_l  Position  returnsB&H  \
# Date
# 2017-04-06    62.362961    57.495259    59.497926        -1    0.024773
# 2017-04-07    63.037037    57.580592    59.475481        -1    0.010751
# 2017-04-10    64.177780    57.664889    59.468222        -1    0.017935
# 2017-04-11    64.466667    57.754666    59.467407        -1    0.004491
# 2017-04-12    66.807404    57.909333    59.483333        -1    0.035666
# ...                 ...          ...          ...       ...         ...
# 2024-08-19  1508.400024  1573.185002  1513.040005         1    0.059091
# 2024-08-20  1491.599976  1573.029001  1513.954504         1   -0.011200
# 2024-08-21  1546.099976  1573.579001  1515.413004         1    0.035886
# 2024-08-22  1594.199951  1574.542000  1517.331003         1    0.030636
# 2024-08-23  1582.099976  1575.238999  1519.135004         1   -0.007619
#
#             strategy  position2  strategy2
# Date
# 2017-04-06 -0.024773          0   0.000000
# ...

# %%
data[['returnsB&H', 'strategy2']].sum()
# Out:
# returnsB&H    3.258310
# strategy2     2.027037
# dtype: float64

# %%
data[['returnsB&H', 'strategy2']].sum().apply(np.exp)
# Out:
# returnsB&H    26.005540
# strategy2      7.591556
# dtype: float64

# %%
data[['returnsB&H', 'strategy2']].std()*np.sqrt(252)
# Out:
# returnsB&H    0.354294
# strategy2     0.324368
# dtype: float64

# %%
data[['strategy', 'strategy2']].std()*np.sqrt(252)
# Out:
# strategy     0.355362
# strategy2    0.324368
# dtype: float64

# %% [markdown]
# Creating Function

# %%
def test_strategy(stock, start, end, SMA):
    df = yf.download(stock, start=start, end=end)
    data = df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"] = data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"] = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data['position'] = np.where(data['SMA_S'] > data['SMA_L'],1,-1)
    data['strategy'] = data['returns']*data.position.shift(1)
    data.dropna(inplace=True)
    ret = np.exp(data['strategy'].sum())
    std = data['strategy'].std()*np.sqrt(252)

    return ret, std

# %% [markdown]
# Class

# %%
class SMA_BACKTESTER():
    def __init__(self, symbol,SMA_S, SMA_L,start,end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.result = None
        self.get_data()

    def get_data(self):
        df = yf.download(self.symbol, start=self.start, end=self.end)
        data = df.Close.to_frame()
        data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"] = data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"] = data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2 = data

        return data

    def test_results(self):
        data = self.data2.copy().dropna()
        data['position'] = np.where(data['SMA_S'] > data['SMA_L'],1,-1)
        data['strategy'] = data['returns']*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsBH"] = data["returns"].cumsum().apply(np.exp)
        data['returns_strategy'] = data['strategy'].cumsum().apply(np.exp)
        perf = data['returns_strategy'].iloc[-1]
        outperf = perf - data['returnsBH'].iloc[-1]
        self.results = data

        ret = np.exp(data['strategy'].sum())
        std = data['strategy'].std()*np.sqrt(252)
        return round(perf,6), round(outperf,6)

#         return ret, std

    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{} | SMA_S={} | SMA_L={}".format(self.symbol[:-3], self.SMA_S, self.SMA_L)
            self.results[['returnsBH', 'returns_strategy' ]].plot(title=title, figsize=(12,8))

# %%
tester = SMA_BACKTESTER("TECHM.NS", 50,100, "2000-01-01", "2023-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()   #perf , outperf
# Out:
# (8.667351, 6.378935)

# %%
tester.plot_results()
